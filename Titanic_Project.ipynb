# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\saloni aggarwal\Downloads\train.csv\train.csv")
df.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0     26    92  2011-08-26      87235.57      False        61.10       3.796
# 1     34    22  2011-03-25       5945.97      False        53.11       3.480
# 2     21    28  2010-12-03       1219.89      False        50.43       2.708
# 3      8     9  2010-09-17      11972.71      False        75.32       2.582
# 4     19    55  2012-05-18       8271.82      False        58.81       4.029
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  136.213613
# 1        NaN        NaN        NaN        NaN        NaN  128.616064
# 2        NaN        NaN        NaN        NaN        NaN  211.265543
# 3        NaN        NaN        NaN        NaN        NaN  214.878556
# 4   12613.98        NaN       11.5    1705.28    3600.79  138.106581
#
#    Unemployment Type    Size
# 0         7.767    A  152513
# 1        10.398    A  158114
# 2         8.163    B  140167
# 3         6.315    A  155078
# 4         8.150    A  203819

# %%
df.shape
df.info()
df.isnull().sum()
predictions[:5]
print("MAE:", mae)
print("R2 Score:", r2)
importance.sort_values(ascending=False).head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282451 entries, 0 to 282450
# Data columns (total 19 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         282451 non-null  int64
#  1   Dept          282451 non-null  int64
#  2   Weekly_Sales  282451 non-null  float64
#  3   IsHoliday     282451 non-null  int64
#  4   Temperature   282451 non-null  float64
#  5   Fuel_Price    282451 non-null  float64
#  6   MarkDown1     282451 non-null  float64
#  7   MarkDown2     282451 non-null  float64
#  8   MarkDown3     282451 non-null  float64
#  9   MarkDown4     282451 non-null  float64
#  10  MarkDown5     282451 non-null  float64
#  11  CPI           282451 non-null  float64
#  12  Unemployment  282451 non-null  float64
#  13  Size          282451 non-null  int64
#  14  Type_B        282451 non-null  bool
#  15  Type_C        282451 non-null  bool
#  16  year          282451 non-null  int32
#  17  month         282451 non-null  int32
#  18  week          282451 non-null  UInt32
# dtypes: UInt32(1), bool(2), float64(10), int32(2), int64(4)
# memory usage: 34.2 MB
# MAE: 1524.472627648652
# R2 Score: 0.9717140317220861
# Dept            0.627838
# Size            0.188855
# Store           0.056659
# week            0.035819
# CPI             0.027336
# Unemployment    0.012353
# Type_B          0.011159
# Temperature     0.010503
# MarkDown3       0.010009
# Fuel_Price      0.005189
# dtype: float64

# %%
import seaborn as sns
sns.histplot(df['Weekly_Sales'], bins=50)
# Out:
# <Axes: xlabel='Weekly_Sales', ylabel='Count'>
